# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit, differential_evolution
import warnings

# %%
#Load dataset
df = pd.read_csv('../data.csv')

# %%
#Extract data
xData = df['Final concentration of M.B. (Cf) (mg/l)'].values
yData = df['amount of adsorbed by adsorbent at equilibrium (qe) (mg/g)'].values

# %%
#Redlich_Peterson model
def func(x, KR, aR, g):
    return (KR * x)/(1+aR * (x ** g))

# %%
#Error function
def sum_of_squared_error(parameter_tuple):
    warnings.filterwarnings("ignore")
    val = func(xData, *parameter_tuple)
    return np.sum((yData - val) ** 2.0)

# %%
#Initial parameter estimation using generic algorithm
def generate_initial_parameters():
    parameter_bounds=[]
    parameter_bounds.append([0.001, 1000]) #KR bounds
    parameter_bounds.append([0.0001, 100]) #aR bounds
    parameter_bounds.append([0.01, 1]) #g bounds (0<g<1)

    result = differential_evolution(sum_of_squared_error, parameter_bounds, seed=3)
    return result.x

# %%
#Generate initial parameters
genetic_parameters = generate_initial_parameters()

# %%
#Curve fitting
fitted_parameters, pcov = curve_fit(func, xData, yData, genetic_parameters, maxfev=10000)

KR, aR, g = fitted_parameters
print(f'Parameters (KR, aR, g)=({KR}, {aR}, {g})')
# Out:
# Parameters (KR, aR, g)=(3.6699265444864784, 3.5231315943645827, 0.5129960203662474)

# %%
#Predictions
model_predictions = func(xData, *fitted_parameters)

# %%
#Error Calculation
absolute_error = abs(model_predictions - yData)
squared_error = np.square(absolute_error)
mse = np.mean(squared_error)
rmse = np.sqrt(mse)
n=len(yData)
p=3 #no. of parameters

hybrid = (100.0/(n-p)) * np.sum(squared_error/yData)
mpsd = 100.0*np.sqrt((1.0/(n-p)) * np.sum(np.square(absolute_error/yData)))
chi_square = np.sum(squared_error/yData)

# %%
#Output results
print('ERRSQ:      ', np.sum(squared_error))
print('RMSE:       ', rmse)
print('HYBRID:     ', hybrid)
print('EABS:       ', np.sum(absolute_error))
print('MPSD:       ', mpsd)
print('Chi-square: ', chi_square)
# Out:
# ERRSQ:       0.001967339204926862
# RMSE:        0.015681753748093923
# HYBRID:      0.09403855839870502
# EABS:        0.11345031017646001
# MPSD:        6.928376153165821
# Chi-square:  0.004701927919935251

# %%
#Plotting
def plot():
    plt.figure(figsize=(8,6))

    #Scatter plot
    plt.scatter(xData, yData, marker='D', label='Experimental Data')

    #Model Curve
    xModel = np.linspace(min(xData), max(xData), 100)
    yModel = func(xModel, *fitted_parameters)

    plt.plot(xModel, yModel,color='red', label='Redlich-Peterson Fit')

    plt.title('Redlich-Peterson Isotherm')
    plt.xlabel('Ce (mg/L)')
    plt.ylabel('Qe (mg/g)')
    plt.legend()
    plt.grid()

    plt.show()

plot()
